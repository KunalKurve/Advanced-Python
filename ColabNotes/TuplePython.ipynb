# %%
a=12,13,14,"a" #packing of tuple
a1=(1,2,3,4) #packing of tuple
x,y,z,w = a #unpacking of tuple , it will assign value as x=12,y=13,z=13,w="a"
print(x,y,z,w)
# Out:
# 12 13 14 a

# %%
a=12
b=14
b,a=a,b #swap the values
print(a,b)
# Out:
# 14 12

# %%
a=(12) # parenthesis are not must so it will store it as int
print(type(a))

a=12,  #it will create a tuple of length of 1
print(type(a))

b=(12,)  # It will create a tuple of length 1
print(type(b))

a1 = tuple([1,2,3])
print(a1,type(a1))
# Out:
# <class 'int'>
# <class 'tuple'>
# <class 'tuple'>
# (1, 2, 3) <class 'tuple'>

# %%
def addition(x,y):
  x=x+10
  y=y+20
  print("In Function",x,y)
  return x+y,x,y #returning multiple values i.e. tuple
x=10
y=20
s,a,b=addition(x,y) #unpacking of tuple
print(s,a,b)
print(x,y)
# Out:
# In Function 20 40
# 60 20 40
# 10 20

# %%
def fun1(a,b=3,*t): # * is expansion variable , t is tuple can store multiple values or null
  print(a,b)
  print(t)
fun1(1,2,3,4,5,"a")
# Out:
# 1 2
# (3, 4, 5, 'a')

# %%
def findsum(a=23,b=10,*t):
  s=a+b
  print("In function",a,b,s)
  if n in t:
    s=s+n
  return
